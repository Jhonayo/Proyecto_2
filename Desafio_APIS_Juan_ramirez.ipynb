# %% [markdown]
# # Extraccion de datos desde una API

# %% [markdown]
# Se selecciona una api que tiene concordancia con la información de los avances anteriores de datos de partidos de la NBA

# %%
pip install nba_api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#se importan las librerias de la api que se utilizaran para la extraccion de datos
from nba_api.stats.endpoints import leaguedashteamstats
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams
import pandas as pd
import json

# %%
gamefinder = leaguegamefinder.LeagueGameFinder()
games = gamefinder.get_data_frames()[0]
print(f'El dataset contiene : {games.shape[0]} filas y {games.shape[1]} columnas.')
print(f'Las columnas del dataset son: {games.columns}')
# Out:
# El dataset contiene : 30000 filas y 28 columnas.
# Las columnas del dataset son: Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
print('El dataset es:')
games.sample(10).sort_values('SEASON_ID')
# Out:
# El dataset es:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 7920      12022         241               DUX       DUX Infinitos  2212200566
# 26460     22018  1610612752               NYK     New York Knicks  0021800155
# 23827     22018  1610612755               PHI  Philadelphia 76ers  0021800938
# 16733     22020  1610612752               NYK     New York Knicks  0022000308
# 4209      22022  1610612741               CHI       Chicago Bulls  0022200336
# 3778      22022  1610612742               DAL    Dallas Mavericks  0022200456
# 2280      32022  1610616847               PAU            Team Pau  0032200004
# 7543      52022         278               HDZ             Handlez  2252200048
# 5873      72022         217               MVG         Mavs Gaming  2272200230
# 6152      72022         231               HVG    Hornets Venom GT  2272200076
#
#         GAME_DATE      MATCHUP    WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  \
# ...

# %% [markdown]
# ---
